# %% [markdown]
# # Layer Examples

# %%
import os

import Layer
import numpy as np

# %%
access_token = os.getenv('MAPBOX_ACCESS_TOKEN')
view_options = {
    'center': [37.17407153, 126.9086032],
    'zoom': 10,
    'bearing': 0,
    'pitch': 60,
    'frame_height': '700px',
    'style': 'mapbox://styles/mapbox/dark-v9',
    'access_token': access_token,
}

# %% [markdown]
# ## Arc Layer

# %%
data = [
    {
        'from': {
            'name': 'Hwaseong',
            'coordinates': [126.9086032, 37.17407153]
        },
        'to': {
            'name': 'Seoul',
            'coordinates': [126.986, 37.541]
        }
    }
]

# %%
arc_layer = Layer.ArcLayer(data, **view_options)

# %%
arc_layer.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.0.0/dist.min.js'></script>
#
#     <!-- only if base map is needed -->
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.css' rel='stylesheet' />
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#     const deckgl = new deck.DeckGL({
#
#         container: 'container',
#         mapboxApiAccessToken: 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw',
#         latitude: 37.17407153,
#         longitude: 126.9086032,
#         zoom: 10,
#         bearing: 0,
#         pitch: 60,
#         mapStyle: 'mapbox://styles/mapbox/dark-v9',
#
#
#
#     layers: [
#         new deck.ArcLayer({
#             'id': 'ArcLayer',
#             'data': [{'from': {'name': 'Hwaseong', 'coordinates': [126.9086032, 37.17407153]}, 'to': {'name': 'Seoul', 'coordinates': [126.986, 37.541]}}],
#             // Styles
#             'widthUnits': 'pixels',
#             'widthScale': 1,
#             'widthMinPixels': 0,
#             'widthMaxPixels': 9007199254740991,
#             'getSourcePosition': d => d.from.coordinates,
#             'getTargetPosition': d => d.to.coordinates,
#             'getSourceColor': [0, 0, 0, 255],
#             'getTargetColor': [0, 0, 0, 255],
#             'getWidth': 1,
#             'getHeight': 1,
#             'getTilt': 0
#         })
#     ]
#
#
#     })
#
#
#
#
# </script>
#
#
# </html>" style="width: 100%; height: 500px;"></iframe>

# %% [markdown]
# ## Path Layer

# %%
data = [
    {
        'path': [[126.986, 37.541], [126.9086032, 37.17407153]],
        'name': 'Seoul-Hwaseong',
        'color': [255, 30, 100]
    },
    {
        'path': [[126.986, 37.541], [127.179108, 37.245635]],
        'name': 'Seoul-Suwon',
        'color': [200, 100, 30]
    }
]

# %%
path_layer = Layer.PathLayer(data, 
                             width=5,
                             widthScale=20,
                             widthMinPixels=2,
                             **view_options)

# %%
path_layer.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.0.0/dist.min.js'></script>
#
#     <!-- only if base map is needed -->
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.css' rel='stylesheet' />
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#     const deckgl = new deck.DeckGL({
#
#         container: 'container',
#         mapboxApiAccessToken: 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw',
#         latitude: 37.17407153,
#         longitude: 126.9086032,
#         zoom: 10,
#         bearing: 0,
#         pitch: 60,
#         mapStyle: 'mapbox://styles/mapbox/dark-v9',
#
#
#
#     layers: [
#         new deck.PathLayer({
#             'id': 'PathLayer',
#             'data': [{'path': [[126.986, 37.541], [126.9086032, 37.17407153]], 'name': 'Seoul-Hwaseong', 'color': [255, 30, 100]}, {'path': [[126.986, 37.541], [127.179108, 37.245635]], 'name': 'Seoul-Suwon', 'color': [200, 100, 30]}],
#             'pickable': false,
#             // Styles
#             'widthScale': 20,
#             'widthMinPixels': 2,
#             'widthMaxPixels': 9007199254740991,
#             'rounded': false,
#             'billboard': false,
#             'miterLimit': 4,
#             'dashJustified': false,
#             'getPath': d => d.path,
#             'getColor': d => colorToRGBArray(d.color),
#             'getWidth': d => 5,
#             //'onHover': ({object, x, y}) => {
#             //    const tooltip = object.name
#             //}
#         })
#     ]
#
#
#     })
#
#
#
#
# </script>
#
#
# </html>" style="width: 100%; height: 500px;"></iframe>

# %% [markdown]
# ## Trips Layer

# %%
paths = [
    {
        'path': [[126.81561169069604, 37.08218248972286],
                  [126.81694879927656, 37.08192703057454],
                  [126.82058506532772, 37.08345425470472],
                  [126.82642187278732, 37.08594720874324],
                  [126.82831786376109, 37.08140909828359],
                  [126.83028046191004, 37.07886194207198],
                  [126.83399231816769, 37.0734428447721],
                  [126.83761076282099, 37.069384103175935],
                  [126.83795179514074, 37.067663541757256],
                  [126.8387065894608, 37.06699779260753],
                  [126.84606088258417, 37.06672832706917],
                  [126.84960718262685, 37.070174985483625],
                  [126.85444990852619, 37.06046761130322],
                  [126.85553592453233, 37.05699083922621],
                  [126.85635420651882, 37.052369373371995],
                  [126.85463875277742, 37.04998844617861],
                  [126.85204329143367, 37.04176370530994],
                  [126.84662056554762, 37.037944216429445],
                  [126.8440176576777, 37.037963591237336],
                  [126.84324898240689, 37.03464663511071],
                  [126.84387252551556, 37.03748583211465],
                  [126.84663076618716, 37.03780508613006],
                  [126.85212786490005, 37.041628643783056],
                  [126.85465025479915, 37.0498533003424],
                  [126.85642165892156, 37.0523694559248],
                  [126.85560331205141, 37.05702696472576],
                  [126.85453942013265, 37.06069298855781],
                  [126.8495169014274, 37.07033706130232],
                  [126.84591452407986, 37.066818241654104],
                  [126.83885251431339, 37.06711513109574],
                  [126.83809787466195, 37.0677087963154],
                  [126.83772311165343, 37.06942931155262],
                  [126.83409318797258, 37.073596167921814],
                  [126.83047144100027, 37.07895232384016],
                  [126.82832808542899, 37.08185964408305],
                  [126.82652726234878, 37.08591491286393],
                  [126.8210099396857, 37.08845823048677],
                  [126.81665334666609, 37.08874406473381],
                  [126.81582783195088, 37.082250988510175]],
        'name': 'bus',
        'color': [255, 30, 100]
    },
]

view_options['center'] = [37.08218248972286, 126.81561169069604]
view_options['zoom'] = 12

# %%
trips = []
time_unit = 1
for data in paths:
    segments = []
    for idx, point in enumerate(data['path']):
        segments.append([point[0], point[1], idx*time_unit])
    data['segments'] = segments
    del data['path']
    trips.append(data)

# %%
trip_layer = Layer.TripsLayer(trips, 
                             width=5,
                             widthScale=20,
                             widthMinPixels=2,
                             currentTime=10,
                             rounded=True,
                             **view_options)
trip_layer.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.0.0/dist.min.js'></script>
#
#     <!-- only if base map is needed -->
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.css' rel='stylesheet' />
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#     const deckgl = new deck.DeckGL({
#
#         container: 'container',
#         mapboxApiAccessToken: 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw',
#         latitude: 37.08218248972286,
#         longitude: 126.81561169069604,
#         zoom: 12,
#         bearing: 0,
#         pitch: 60,
#         mapStyle: 'mapbox://styles/mapbox/dark-v9',
#
#
#
#     layers: [
#         new deck.TripsLayer({
#             'id': 'TripsLayer',
#             'data': [{'name': 'bus', 'color': [255, 30, 100], 'segments': [[126.81561169069604, 37.08218248972286, 0], [126.81694879927656, 37.08192703057454, 1], [126.82058506532772, 37.08345425470472, 2], [126.82642187278732, 37.08594720874324, 3], [126.82831786376109, 37.08140909828359, 4], [126.83028046191004, 37.07886194207198, 5], [126.83399231816769, 37.0734428447721, 6], [126.83761076282099, 37.069384103175935, 7], [126.83795179514074, 37.067663541757256, 8], [126.8387065894608, 37.06699779260753, 9], [126.84606088258417, 37.06672832706917, 10], [126.84960718262685, 37.070174985483625, 11], [126.85444990852619, 37.06046761130322, 12], [126.85553592453233, 37.05699083922621, 13], [126.85635420651882, 37.052369373371995, 14], [126.85463875277742, 37.04998844617861, 15], [126.85204329143367, 37.04176370530994, 16], [126.84662056554762, 37.037944216429445, 17], [126.8440176576777, 37.037963591237336, 18], [126.84324898240689, 37.03464663511071, 19], [126.84387252551556, 37.03748583211465, 20], [126.84663076618716, 37.03780508613006, 21], [126.85212786490005, 37.041628643783056, 22], [126.85465025479915, 37.0498533003424, 23], [126.85642165892156, 37.0523694559248, 24], [126.85560331205141, 37.05702696472576, 25], [126.85453942013265, 37.06069298855781, 26], [126.8495169014274, 37.07033706130232, 27], [126.84591452407986, 37.066818241654104, 28], [126.83885251431339, 37.06711513109574, 29], [126.83809787466195, 37.0677087963154, 30], [126.83772311165343, 37.06942931155262, 31], [126.83409318797258, 37.073596167921814, 32], [126.83047144100027, 37.07895232384016, 33], [126.82832808542899, 37.08185964408305, 34], [126.82652726234878, 37.08591491286393, 35], [126.8210099396857, 37.08845823048677, 36], [126.81665334666609, 37.08874406473381, 37], [126.81582783195088, 37.082250988510175, 38]]}],
#             'pickable': false,
#             // Styles
#             // PathLayer (inherited)
#             'widthScale': 20,
#             'widthMinPixels': 2,
#             'widthMaxPixels': 9007199254740991,
#             'rounded': true,
#             'billboard': false,
#             'miterLimit': 4,
#             'dashJustified': false,
#             'getColor': d => colorToRGBArray(d.color),
#             'getWidth': d => 5,
#             'onHover': ({object, x, y}) => {
#                 const tooltip = object.name
#             },
#             // TripsLayer Added.
#             getPath: d => d.segments,
#             //getPath: d => d.waypoints.map(p => p.coordinates),
#             //getTimestamps: d => d.waypoints.map(p => p.timestamp),
#             opacity: 1,
#             trailLength: 120,
#             currentTime: 10
#         })
#     ]
#
#
#     })
#
#
#
#
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## Overay Layers

# %%
data = [
    {
        'from': {
            'name': 'Hwaseong',
            'coordinates': [126.9086032, 37.17407153]
        },
        'to': {
            'name': 'Seoul',
            'coordinates': [126.986, 37.541]
        }
    }
]

data2 = [
    {
        'from': {
            'name': '경주',
            'coordinates': [128.162384, 36.416862]
        },
        'to': {
            'name': 'Seoul',
            'coordinates': [126.986, 37.541]
        }
    }
]

# %%
m = Layer.Map(**view_options)

# %%
arc_layer = Layer.ArcLayer(data, **view_options)
arc_layer2 = Layer.ArcLayer(data2, **view_options)
m.add(arc_layer)
m.add(arc_layer2)

# %%
m.show()
# Out:
# /Users/heumsi/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/display.py:689: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.0.0/dist.min.js'></script>
#
#     <!-- only if base map is needed -->
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.css' rel='stylesheet' />
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#     const deckgl = new deck.DeckGL({
#
#         container: 'container',
#         mapboxApiAccessToken: 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw',
#         latitude: 37.17407153,
#         longitude: 126.9086032,
#         zoom: 10,
#         bearing: 0,
#         pitch: 60,
#         mapStyle: 'mapbox://styles/mapbox/dark-v9',
#         layers: [, new deck.ArcLayer({
#     'id': 'ArcLayer',
#     'data': [{'from': {'name': 'Hwaseong', 'coordinates': [126.9086032, 37.17407153]}, 'to': {'name': 'Seoul', 'coordinates': [126.986, 37.541]}}],
#     // Styles
#     'widthUnits': 'pixels',
#     'widthScale': 1,
#     'widthMinPixels': 0,
#     'widthMaxPixels': 9007199254740991,
#     'getSourcePosition': d => d.from.coordinates,
#     'getTargetPosition': d => d.to.coordinates,
#     'getSourceColor': [0, 0, 0, 255],
#     'getTargetColor': [0, 0, 0, 255],
#     'getWidth': 1,
#     'getHeight': 1,
#     'getTilt': 0
# })
# , new deck.ArcLayer({
#     'id': 'ArcLayer',
#     'data': [{'from': {'name': '경주', 'coordinates': [128.162384, 36.416862]}, 'to': {'name': 'Seoul', 'coordinates': [126.986, 37.541]}}],
#     // Styles
#     'widthUnits': 'pixels',
#     'widthScale': 1,
#     'widthMinPixels': 0,
#     'widthMaxPixels': 9007199254740991,
#     'getSourcePosition': d => d.from.coordinates,
#     'getTargetPosition': d => d.to.coordinates,
#     'getSourceColor': [0, 0, 0, 255],
#     'getTargetColor': [0, 0, 0, 255],
#     'getWidth': 1,
#     'getHeight': 1,
#     'getTilt': 0
# })
# ]
#     })
#
#
#
#
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## Scatterplot Layer

# %%
data = \
[{'name': 'Seoul',
  'coordinates': [126.986, 37.541]},
 {'name': 'Canton Tremblay',
  'coordinates': [ 126.9086032, 37.17407153]},]

# %%
m = Layer.Map(**view_options)
scatterplot_Layer = Layer.ScatterplotLayer(data, radiusScale=10, radius=50000)
m.add(scatterplot_Layer)

# %%
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.0.0/dist.min.js'></script>
#
#     <!-- only if base map is needed -->
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.css' rel='stylesheet' />
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#     const deckgl = new deck.DeckGL({
#
#         container: 'container',
#         mapboxApiAccessToken: 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw',
#         latitude: 37.17407153,
#         longitude: 126.9086032,
#         zoom: 10,
#         bearing: 0,
#         pitch: 60,
#         mapStyle: 'mapbox://styles/mapbox/dark-v9',
#         layers: [new deck.ScatterplotLayer({
#     'id': 'ScatterplotLayer',
#     'data': [{'name': 'Seoul', 'coordinates': [126.986, 37.541]}, {'name': 'Canton Tremblay', 'coordinates': [126.9086032, 37.17407153]}],
#     'radiusScale': 10,
#     'lineWidthUnits': 'meters',
#     'lineWdithScale': 1,
#     'stroked': false,
#     'filled': true,
#     'radiusMinPixels': 0,
#     'radiusMaxPixels': 0,
#     'lineWidthMinPixels': 0,
#     'lineWidthMaxPixels': 9007199254740991,
#     'getPosition': d => d.coordinates,
#     'getRadius': d => 50000,
#     'getFillColor': d => [255, 140, 0],
#     'getLineColor': d => [0, 0, 0],
# })
# ,]
#     })
#
#
#
#
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## GridCell Layer

# %%
import pandas as pd
rental = pd.read_csv('/Users/heumsi/Desktop/note/open_data_project/seoul_bike/data/서울특별시 공공자전거 대여소 정보.csv')

# %%
data = []
for coord in rental[['경도', '위도']].values.tolist():
    data.append({"coordinates" : coord, "value":np.random.randint(1000)})

# %%
m = Layer.Map(**view_options)
GridCellLayer = Layer.GridCellLayer(data)
m.add(GridCellLayer)

# %%
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <!-- <script src='https://unpkg.com/deck.gl@~7.0.0/dist.min.js'></script> -->
#     <script src='https://unpkg.com/@deck.gl/core@~7.0.0/dist.min.js'></script>
#     <script src='https://unpkg.com/@deck.gl/layers@~7.0.0/dist.min.js'></script>
#     <script src='https://unpkg.com/@deck.gl/aggregation-layers@~7.0.0/dist.min.js'></script>
#
#     <!-- only if base map is needed -->
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.css' rel='stylesheet' />
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#     const deckgl = new deck.DeckGL({
#
#         container: 'container',
#         mapboxApiAccessToken: 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw',
#         latitude: 37.17407153,
#         longitude: 126.9086032,
#         zoom: 10,
#         bearing: 0,
#         pitch: 60,
#         mapStyle: 'mapbox://styles/mapbox/dark-v9',
#         layers: [new deck.GridCellLayer({
#     id: 'GridCellLayer',
#     data: [{'coordinates': [127.02179, 37.524071], 'value': 256}, {'coordinates': [127.024277, 37.505581], 'value': 832}, {'coordinates': [127.021477, 37.511517], 'value': 77}, {'coordinates': [127.035835, 37.512527], 'value': 847}, {'coordinates': [127.034508, 37.520641], 'value': 477}, {'coordinates': [127.02871699999999, 37.527122], 'value': 276}, {'coordinates': [127.038559, 37.528614000000005], 'value': 729}, {'coordinates': [127.035599, 37.529301000000004], 'value': 170}, {'coordinates': [127.04938500000002, 37.518902000000004], 'value': 572}, {'coordinates': [127.040176, 37.523613], 'value': 568}, {'coordinates': [127.043022, 37.517773], 'value': 866}, {'coordinates': [127.05632800000001, 37.520579999999995], 'value': 38}, {'coordinates': [127.052467, 37.525116], 'value': 684}, {'coordinates': [127.061035, 37.521275], 'value': 92}, {'coordinates': [127.06111899999999, 37.514247999999995], 'value': 513}, {'coordinates': [127.0662, 37.515888000000004], 'value': 75}, {'coordinates': [127.055031, 37.513577000000005], 'value': 650}, {'coordinates': [127.05468, 37.506607], 'value': 870}, {'coordinates': [127.056969, 37.491928], 'value': 104}, {'coordinates': [127.06944299999999, 37.496117], 'value': 66}, {'coordinates': [127.063103, 37.508091], 'value': 124}, {'coordinates': [127.06720700000001, 37.502213], 'value': 183}, {'coordinates': [127.066223, 37.500439], 'value': 227}, {'coordinates': [127.05931899999999, 37.49865], 'value': 432}, {'coordinates': [127.0588, 37.502396000000005], 'value': 772}, {'coordinates': [127.03146399999999, 37.490551], 'value': 864}, {'coordinates': [127.04264099999999, 37.503586], 'value': 130}, {'coordinates': [127.04319, 37.502357], 'value': 233}, {'coordinates': [127.03945900000001, 37.492199], 'value': 276}, {'coordinates': [127.044601, 37.498051000000004], 'value': 163}, {'coordinates': [127.048965, 37.504208], 'value': 349}, {'coordinates': [127.03407299999999, 37.485157], 'value': 872}, {'coordinates': [127.045898, 37.493759000000004], 'value': 513}, {'coordinates': [127.046761, 37.486767], 'value': 143}, {'coordinates': [127.04746200000001, 37.494236], 'value': 579}, {'coordinates': [127.071976, 37.492077], 'value': 496}, {'coordinates': [127.052299, 37.483261], 'value': 694}, {'coordinates': [127.045174, 37.477509000000005], 'value': 746}, {'coordinates': [127.084938, 37.483311], 'value': 202}, {'coordinates': [127.07951399999999, 37.494007], 'value': 591}, {'coordinates': [127.107727, 37.465317], 'value': 919}, {'coordinates': [127.101196, 37.465061], 'value': 411}, {'coordinates': [127.0354, 37.518639], 'value': 33}, {'coordinates': [127.056854, 37.507233], 'value': 269}, {'coordinates': [127.03856699999999, 37.501545], 'value': 22}, {'coordinates': [127.047905, 37.494823], 'value': 41}, {'coordinates': [127.089027, 37.483878999999995], 'value': 66}, {'coordinates': [127.035027, 37.517590000000006], 'value': 344}, {'coordinates': [127.040474, 37.516811], 'value': 93}, {'coordinates': [127.05676299999999, 37.519787], 'value': 267}, {'coordinates': [127.06230900000001, 37.509121], 'value': 328}, {'coordinates': [127.047119, 37.51807], 'value': 957}, {'coordinates': [127.04276999999999, 37.501948999999996], 'value': 684}, {'coordinates': [127.053917, 37.481384000000006], 'value': 474}, {'coordinates': [127.050377, 37.475605], 'value': 964}, {'coordinates': [127.041389, 37.492809], 'value': 639}, {'coordinates': [127.028259, 37.526844], 'value': 572}, {'coordinates': [127.022453, 37.517635], 'value': 52}, {'coordinates': [127.02746599999999, 37.51918], 'value': 557}, {'coordinates': [127.031898, 37.52124], 'value': 478}, {'coordinates': [127.038475, 37.5233], 'value': 414}, {'coordinates': [127.041298, 37.489342], 'value': 291}, {'coordinates': [127.052872, 37.505428], 'value': 503}, {'coordinates': [127.054298, 37.496552], 'value': 8}, {'coordinates': [127.035133, 37.514748], 'value': 611}, {'coordinates': [127.063797, 37.494499], 'value': 318}, {'coordinates': [127.065575, 37.489277], ' ...

# %% [markdown]
# ## CPUGrid Layer

# %%
import pandas as pd
rental = pd.read_csv('/Users/heumsi/Desktop/note/open_data_project/seoul_bike/data/서울특별시 공공자전거 대여소 정보.csv')

# %%
rental.head()
# Out:
#     구명   대여소ID  대여소번호                      대여소명  \
# 0  강남구  ST-777   2301                현대고등학교 건너편
# 1  강남구  ST-787   2302  교보타워 버스정류장(신논현역 3번출구 후면)
# 2  강남구  ST-788   2303                  논현역 7번출구
# 3  강남구  ST-789   2304         신영 ROYAL PALACE 앞
# 4  강남구  ST-790   2305              MCM 본사 직영점 앞
#
#                               대여소 주소  거치대수         위도          경도
# 0       서울특별시 강남구 압구정로 134현대고등학교 건너편    10  37.524071  127.021790
# 1    서울특별시 강남구 봉은사로 지하 102교보타워 버스정류장    10  37.505581  127.024277
# 2       서울특별시 강남구 학동로 지하 102논현역 7번출구    15  37.511517  127.021477
# 3  서울특별시 강남구 언주로 626신영 ROYAL PALACE앞    10  37.512527  127.035835
# 4      서울특별시 강남구 언주로 734MCM 본사 직영점 앞    10  37.520641  127.034508

# %%
data = []
for coord in rental[['위도', '경도']].values.tolist():
    data.append({"coordinates" : coord})
data = data[:10]

# %%
m = Layer.Map(**view_options)
CPUGridLayer = Layer.CPUGridLayer(data)
m.add(CPUGridLayer)

# %%
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <!-- <script src='https://unpkg.com/deck.gl@~7.0.0/dist.min.js'></script> -->
#     <script src='https://unpkg.com/@deck.gl/core@~7.0.0/dist.min.js'></script>
#     <script src='https://unpkg.com/@deck.gl/layers@~7.0.0/dist.min.js'></script>
#     <script src='https://unpkg.com/@deck.gl/aggregation-layers@~7.0.0/dist.min.js'></script>
#
#     <!-- only if base map is needed -->
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.css' rel='stylesheet' />
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#     const deckgl = new deck.DeckGL({
#
#         container: 'container',
#         mapboxApiAccessToken: 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw',
#         latitude: 37.17407153,
#         longitude: 126.9086032,
#         zoom: 10,
#         bearing: 0,
#         pitch: 60,
#         mapStyle: 'mapbox://styles/mapbox/dark-v9',
#         layers: [
# new deck.CPUGridLayer({}),]
#     })
#
#
#
#
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>
