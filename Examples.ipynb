# %% [markdown]
# # Layer Examples

# %%
import os

import Layer
import numpy as np

# %%
access_token = os.getenv('MAPBOX_ACCESS_TOKEN')
view_options = {
    'center': [37.17407153, 126.9086032],
    'zoom': 10,
    'bearing': 0,
    'pitch': 60,
    'height': '700px',
    'style': 'mapbox://styles/mapbox/light-v9',
    'access_token': access_token,
}

# %% [markdown]
# ## Arc Layer

# %%
Layer.ArcLayer?
# Out:
# Init signature:
# Layer.ArcLayer(
#     data,
#     id='ArcLayer',
#     source_color=[0, 0, 0, 255],
#     target_color=[0, 0, 0, 255],
#     widthUnits='pixels',
#     widthScale=1,
#     widthMinPixels=0,
#     widthMaxPixels=9007199254740991,
#     getSourcePosition='object => object.sourcePosition',
#     getTargetPosition='object => object.targetPosition',
#     getSourceColor=[0, 0, 0, 255],
#     getTargetColor=[0, 0, 0, 255],
#     getWidth=1,
#     getHeight=1,
#     getTilt=0,
#     *args,
#     **kwargs,
# )
# Docstring:      <no docstring>
# File:           ~/Desktop/dev/deckgl_jupyter/Layer.py
# Type:           type
# Subclasses:

# %%
data = [
    {
        'name': 'Hwaseong - Seoul',
        'sourcePosition': [126.908, 37.174],
        'targetPosition': [126.986, 37.541]
    },
    {
        'name': 'Seoul-Suwon',
        'sourcePosition': [126.986, 37.541],
        'targetPosition': [127.179, 37.245]
    }
]

# %%
m = Layer.Map(**view_options)
arc_layer = Layer.ArcLayer(data)
m.add(arc_layer)
m.show()
# Out:
# /Users/heumsi/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/display.py:689: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.0.0/dist.min.js'></script>
#
#     <!-- only if base map is needed -->
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.css' rel='stylesheet' />
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#     const deckgl = new deck.DeckGL({
#
#         container: 'container',
#         mapboxApiAccessToken: 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw',
#         latitude: 37.17407153,
#         longitude: 126.9086032,
#         zoom: 10,
#         bearing: 0,
#         pitch: 60,
#         mapStyle: 'mapbox://styles/mapbox/light-v9',
#         layers: [new deck.ArcLayer({
#     // ArcLayer Added.
#     'widthUnits': 'pixels',
#     'widthScale': 1,
#     'widthMinPixels': 0,
#     'widthMaxPixels': 9007199254740991,
#     'getSourcePosition': object => object.sourcePosition,
#     'getTargetPosition': object => object.targetPosition,
#     'getSourceColor': [0, 0, 0, 255],
#     'getTargetColor': [0, 0, 0, 255],
#     'getWidth': 1,
#     'getHeight': 1,
#     'getTilt': 0,
#
#     /// MapLayer (inherited)
#     'data' : [{'name': 'Hwaseong - Seoul', 'sourcePosition': [126.908, 37.174], 'targetPosition': [126.986, 37.541]}, {'name': 'Seoul-Suwon', 'sourcePosition': [126.986, 37.541], 'targetPosition': [127.179, 37.245]}],
#     'id' : 'ArcLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': ({object, x, y}) => {
#         const tooltip = null
#     },
#     //'onClick' : null,
#     //'onDragStart' : null,
#     //'onDrag' : null,
#     //'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# })
# ,]
#     })
#
#
#
#
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## Path Layer

# %%
Layer.PathLayer?
# Out:
# Init signature:
# Layer.PathLayer(
#     data,
#     id='PathLayer',
#     widthUnits=1,
#     widthScale=1,
#     widthMinPixels=0,
#     widthMaxPixels=9007199254740991,
#     rounded=False,
#     billboard=False,
#     miterLimit=4,
#     dashJustified=False,
#     getPath='object => object.path',
#     getColor=[0, 0, 0, 255],
#     getWidth=1,
#     getDashArray=None,
#     *args,
#     **kwargs,
# )
# Docstring:      <no docstring>
# File:           ~/Desktop/dev/deckgl_jupyter/Layer.py
# Type:           type
# Subclasses:     TripsLayer

# %%
data = [
    {
        'path': [[126.986, 37.541], [126.9086032, 37.17407153]],
        'name': 'Seoul-Hwaseong',
        'color': [255, 30, 100]
    },
    {
        'path': [[126.986, 37.541], [127.179108, 37.245635]],
        'name': 'Seoul-Suwon',
        'color': [200, 100, 30]
    }
]

# %%
m = Layer.Map(**view_options)
path_layer = Layer.PathLayer(data, 
                             getWidth=10,
                             widthScale=50,
                             getColor='obj => obj.color')
m.add(path_layer)
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.0.0/dist.min.js'></script>
#
#     <!-- only if base map is needed -->
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.css' rel='stylesheet' />
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#     const deckgl = new deck.DeckGL({
#
#         container: 'container',
#         mapboxApiAccessToken: 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw',
#         latitude: 37.17407153,
#         longitude: 126.9086032,
#         zoom: 10,
#         bearing: 0,
#         pitch: 60,
#         mapStyle: 'mapbox://styles/mapbox/light-v9',
#         layers: [new deck.PathLayer({
#     // PathLayer Added.
#     'widthUnits': 1,
#     'widthScale': 50,
#     'widthMinPixels': 0,
#     'widthMaxPixels': 9007199254740991,
#     'rounded': false,
#     'billboard': false,
#     'miterLimit': 4,
#     'getPath': object => object.path,
#     'getColor': obj => obj.color,
#     'getWidth': 10,
#     'dashJustified': false,
#
#     // MapLayer (inherited)
#     'data' : [{'path': [[126.986, 37.541], [126.9086032, 37.17407153]], 'name': 'Seoul-Hwaseong', 'color': [255, 30, 100]}, {'path': [[126.986, 37.541], [127.179108, 37.245635]], 'name': 'Seoul-Suwon', 'color': [200, 100, 30]}],
#     'id' : 'PathLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': ({object, x, y}) => {
#         const tooltip = null
#     },
#     //'onClick' : null,
#     //'onDragStart' : null,
#     //'onDrag' : null,
#     //'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# }),]
#     })
#
#
#
#
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## Trips Layer

# %%
trips = [
    {'name': 'bus',
    'color': [255, 30, 100],
    'path': [
        [126.81561169069604, 37.08218248972286, 0],
        [126.81694879927656, 37.08192703057454, 1],
        [126.82058506532772, 37.08345425470472, 2],
        [126.82642187278732, 37.08594720874324, 3],
        [126.82831786376109, 37.08140909828359, 4],
        [126.83028046191004, 37.07886194207198, 5],
        [126.83399231816769, 37.0734428447721, 6],
        [126.83761076282099, 37.069384103175935, 7],
        [126.83795179514074, 37.067663541757256, 8],
        [126.8387065894608, 37.06699779260753, 9],
        [126.84606088258417, 37.06672832706917, 10],
        [126.84960718262685, 37.070174985483625, 11],
        [126.85444990852619, 37.06046761130322, 12],
        [126.85553592453233, 37.05699083922621, 13],
        [126.85635420651882, 37.052369373371995, 14],
        [126.85463875277742, 37.04998844617861, 15],
        [126.85204329143367, 37.04176370530994, 16],
        [126.84662056554762, 37.037944216429445, 17],
        [126.8440176576777, 37.037963591237336, 18],
        [126.84324898240689, 37.03464663511071, 19],
        [126.84387252551556, 37.03748583211465, 20],
        [126.84663076618716, 37.03780508613006, 21],
        [126.85212786490005, 37.041628643783056, 22],
        [126.85465025479915, 37.0498533003424, 23],
        [126.85642165892156, 37.0523694559248, 24],
        [126.85560331205141, 37.05702696472576, 25],
        [126.85453942013265, 37.06069298855781, 26],
        [126.8495169014274, 37.07033706130232, 27],
        [126.84591452407986, 37.066818241654104, 28],
        [126.83885251431339, 37.06711513109574, 29],
        [126.83809787466195, 37.0677087963154, 30],
        [126.83772311165343, 37.06942931155262, 31],
        [126.83409318797258, 37.073596167921814, 32],
        [126.83047144100027, 37.07895232384016, 33],
        [126.82832808542899, 37.08185964408305, 34],
        [126.82652726234878, 37.08591491286393, 35],
        [126.8210099396857, 37.08845823048677, 36],
        [126.81665334666609, 37.08874406473381, 37],
        [126.81582783195088, 37.082250988510175, 38]]
    }
]

view_options['center'] = [37.08218248972286, 126.81561169069604]
view_options['zoom'] = 12

# %%
m = Layer.Map(**view_options)
trip_layer = Layer.TripsLayer(trips, 
                             getWidth=5,
                             getColor='obj => obj.color',
                             widthScale=20,
                             widthMinPixels=2,
                             currentTime=20,
                             rounded=True)
m.add(trip_layer)
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.0.0/dist.min.js'></script>
#
#     <!-- only if base map is needed -->
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.css' rel='stylesheet' />
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#     const deckgl = new deck.DeckGL({
#
#         container: 'container',
#         mapboxApiAccessToken: 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw',
#         latitude: 37.08218248972286,
#         longitude: 126.81561169069604,
#         zoom: 12,
#         bearing: 0,
#         pitch: 60,
#         mapStyle: 'mapbox://styles/mapbox/light-v9',
#         layers: [new deck.TripsLayer({
#     // TripsLayer Added.
#     'trailLength': 120,
#     'currentTime': 20,
#
#     // PathLayer (inherited)
#     'widthScale': 20,
#     'widthMinPixels': 2,
#     'widthMaxPixels': 9007199254740991,
#     'rounded': true,
#     'billboard': false,
#     'miterLimit': 4,
#     'dashJustified': false,
#
#     'getPath': object => object.path,
#     'getColor': obj => obj.color,
#     'getWidth': 5,
#
#     // MapLayer (inherited)
#     'data' : [{'name': 'bus', 'color': [255, 30, 100], 'path': [[126.81561169069604, 37.08218248972286, 0], [126.81694879927656, 37.08192703057454, 1], [126.82058506532772, 37.08345425470472, 2], [126.82642187278732, 37.08594720874324, 3], [126.82831786376109, 37.08140909828359, 4], [126.83028046191004, 37.07886194207198, 5], [126.83399231816769, 37.0734428447721, 6], [126.83761076282099, 37.069384103175935, 7], [126.83795179514074, 37.067663541757256, 8], [126.8387065894608, 37.06699779260753, 9], [126.84606088258417, 37.06672832706917, 10], [126.84960718262685, 37.070174985483625, 11], [126.85444990852619, 37.06046761130322, 12], [126.85553592453233, 37.05699083922621, 13], [126.85635420651882, 37.052369373371995, 14], [126.85463875277742, 37.04998844617861, 15], [126.85204329143367, 37.04176370530994, 16], [126.84662056554762, 37.037944216429445, 17], [126.8440176576777, 37.037963591237336, 18], [126.84324898240689, 37.03464663511071, 19], [126.84387252551556, 37.03748583211465, 20], [126.84663076618716, 37.03780508613006, 21], [126.85212786490005, 37.041628643783056, 22], [126.85465025479915, 37.0498533003424, 23], [126.85642165892156, 37.0523694559248, 24], [126.85560331205141, 37.05702696472576, 25], [126.85453942013265, 37.06069298855781, 26], [126.8495169014274, 37.07033706130232, 27], [126.84591452407986, 37.066818241654104, 28], [126.83885251431339, 37.06711513109574, 29], [126.83809787466195, 37.0677087963154, 30], [126.83772311165343, 37.06942931155262, 31], [126.83409318797258, 37.073596167921814, 32], [126.83047144100027, 37.07895232384016, 33], [126.82832808542899, 37.08185964408305, 34], [126.82652726234878, 37.08591491286393, 35], [126.8210099396857, 37.08845823048677, 36], [126.81665334666609, 37.08874406473381, 37], [126.81582783195088, 37.082250988510175, 38]]}],
#     'id' : 'TripsLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': ({object, x, y}) => {
#         const tooltip = null
#     },
#     //'onClick' : null,
#     //'onDragStart' : null,
#     //'onDrag' : null,
#     //'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# }),]
#     })
#
#
#
#
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## Scatterplot Layer

# %%
Layer.ScatterplotLayer?
# Out:
# Init signature:
# Layer.ScatterplotLayer(
#     data,
#     id='ScatterplotLayer',
#     radiusScale=1,
#     lineWidthUnits='meters',
#     lineWdithScale=1,
#     stroked=False,
#     filled=True,
#     radiusMinPixels=0,
#     radiusMaxPixels=0,
#     lineWidthMinPixels=0,
#     lineWidthMaxPixels=9007199254740991,
#     getPosition='object => object.position',
#     getRadius=1,
#     getColor=[0, 0, 0, 255],
#     getFillColor=[255, 140, 0],
#     getLineColor=[0, 0, 0],
#     getLineWidth=1,
#     *args,
#     **kwargs,
# )
# Docstring:      <no docstring>
# File:           ~/Desktop/dev/deckgl_jupyter/Layer.py
# Type:           type
# Subclasses:

# %%
data = [
    {
        'name': 'Seoul',
        'coordinates': [126.986, 37.541]
    },
    {
        'name': 'Suwon',
        'coordinates': [126.908, 37.174]
    }
]

# %%
m = Layer.Map(**view_options)
scatterplot_Layer = Layer.ScatterplotLayer(data, 
                                           radiusScale=1000, 
                                           getRadius=5000,
                                           getPosition='obj => obj.coordinates')
m.add(scatterplot_Layer)
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.0.0/dist.min.js'></script>
#
#     <!-- only if base map is needed -->
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.css' rel='stylesheet' />
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#     const deckgl = new deck.DeckGL({
#
#         container: 'container',
#         mapboxApiAccessToken: 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw',
#         latitude: 37.08218248972286,
#         longitude: 126.81561169069604,
#         zoom: 12,
#         bearing: 0,
#         pitch: 60,
#         mapStyle: 'mapbox://styles/mapbox/light-v9',
#         layers: [new deck.ScatterplotLayer({
#     // ScatterplotLayer Added.
#     'radiusScale': 1000,
#     'lineWidthUnits': 'meters',
#     'lineWdithScale': 1,
#     'stroked': false,
#     'filled': true,
#     'radiusMinPixels': 0,
#     'radiusMaxPixels': 0,
#     'lineWidthMinPixels': 0,
#     'lineWidthMaxPixels': 9007199254740991,
#     'getPosition': obj => obj.coordinates,
#     'getRadius': 5000,
#     'getColor': [0, 0, 0, 255],
#     'getFillColor': [255, 140, 0],
#     'getLineColor': [0, 0, 0],
#     'getLineWidth': 1,
#
#     // MapLayer (inherited)
#     'data' : [{'name': 'Seoul', 'coordinates': [126.986, 37.541]}, {'name': 'Canton Tremblay', 'coordinates': [126.908, 37.174]}],
#     'id' : 'ScatterplotLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': ({object, x, y}) => {
#         const tooltip = null
#     },
#     'onClick' : null,
#     'onDragStart' : null,
#     'onDrag' : null,
#     'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# })
# ,]
#     })
#
#
#
#
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## GridCell Layer

# %%
Layer.GridCellLayer?
# Out:
# Init signature:
# Layer.GridCellLayer(
#     data,
#     id='GridCellLayer',
#     cellSize=1000,
#     coverage=1,
#     elevationScale=1,
#     extruded=True,
#     getPosition='x => x.position',
#     getColor=[255, 0, 255, 255],
#     getElevation=1000,
#     *args,
#     **kwargs,
# )
# Docstring:      <no docstring>
# File:           ~/Desktop/dev/deckgl_jupyter/Layer.py
# Type:           type
# Subclasses:

# %%
data = [
    {'coordinates': [126.81561169069604, 37.08218248972286], 'values': 66},
    {'coordinates': [126.82831786376109, 37.08140909828359], 'values': 23},
    {'coordinates': [126.8387065894608, 37.06699779260753], 'values': 58},
    {'coordinates': [126.84606088258417, 37.06672832706917], 'values': 39},
    {'coordinates': [126.84662056554762, 37.037944216429445], 'values': 95},
    {'coordinates': [126.8440176576777, 37.037963591237336], 'values': 5},
    {'coordinates': [126.84591452407986, 37.066818241654104], 'values': 6},
    {'coordinates': [126.83047144100027, 37.07895232384016], 'values': 39},
    {'coordinates': [126.81582783195088, 37.082250988510175], 'values': 26}
]

# %%
m = Layer.Map(**view_options)
GC_layer = Layer.GridCellLayer(data,
                               cellSize=100,
                               getPosition='obj => obj.coordinates')
m.add(GC_layer)
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.0.0/dist.min.js'></script>
#
#     <!-- only if base map is needed -->
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.css' rel='stylesheet' />
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#     const deckgl = new deck.DeckGL({
#
#         container: 'container',
#         mapboxApiAccessToken: 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw',
#         latitude: 37.08218248972286,
#         longitude: 126.81561169069604,
#         zoom: 12,
#         bearing: 0,
#         pitch: 60,
#         mapStyle: 'mapbox://styles/mapbox/light-v9',
#         layers: [new deck.GridCellLayer({
#     // GridCellLayer Added.
#     extruded: true,
#     cellSize: 100,
#     coverage: 1,
#     elevationScale: 1,
#     getPosition: obj => obj.coordinates,
#     getColor: [255, 0, 255, 255],
#     getElevation: 1000,
#
#     // MapLayer (inherited)
#     'data' : [{'coordinates': [126.81561169069604, 37.08218248972286], 'values': 66}, {'coordinates': [126.82831786376109, 37.08140909828359], 'values': 23}, {'coordinates': [126.8387065894608, 37.06699779260753], 'values': 58}, {'coordinates': [126.84606088258417, 37.06672832706917], 'values': 39}, {'coordinates': [126.84662056554762, 37.037944216429445], 'values': 95}, {'coordinates': [126.8440176576777, 37.037963591237336], 'values': 5}, {'coordinates': [126.84591452407986, 37.066818241654104], 'values': 6}, {'coordinates': [126.83047144100027, 37.07895232384016], 'values': 39}, {'coordinates': [126.81582783195088, 37.082250988510175], 'values': 26}],
#     'id' : 'GridCellLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': ({object, x, y}) => {
#         const tooltip = null
#     },
#     'onClick' : null,
#     'onDragStart' : null,
#     'onDrag' : null,
#     'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# }),]
#     })
#
#
#
#
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## Overay Layers

# %%
m = Layer.Map(**view_options)
m.add(trip_layer)
m.add(GC_layer)
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.0.0/dist.min.js'></script>
#
#     <!-- only if base map is needed -->
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.css' rel='stylesheet' />
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#     const deckgl = new deck.DeckGL({
#
#         container: 'container',
#         mapboxApiAccessToken: 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw',
#         latitude: 37.08218248972286,
#         longitude: 126.81561169069604,
#         zoom: 12,
#         bearing: 0,
#         pitch: 60,
#         mapStyle: 'mapbox://styles/mapbox/light-v9',
#         layers: [new deck.TripsLayer({
#     // TripsLayer Added.
#     'trailLength': 120,
#     'currentTime': 20,
#
#     // PathLayer (inherited)
#     'widthScale': 20,
#     'widthMinPixels': 2,
#     'widthMaxPixels': 9007199254740991,
#     'rounded': true,
#     'billboard': false,
#     'miterLimit': 4,
#     'dashJustified': false,
#
#     'getPath': object => object.path,
#     'getColor': obj => obj.color,
#     'getWidth': 5,
#
#     // MapLayer (inherited)
#     'data' : [{'name': 'bus', 'color': [255, 30, 100], 'path': [[126.81561169069604, 37.08218248972286, 0], [126.81694879927656, 37.08192703057454, 1], [126.82058506532772, 37.08345425470472, 2], [126.82642187278732, 37.08594720874324, 3], [126.82831786376109, 37.08140909828359, 4], [126.83028046191004, 37.07886194207198, 5], [126.83399231816769, 37.0734428447721, 6], [126.83761076282099, 37.069384103175935, 7], [126.83795179514074, 37.067663541757256, 8], [126.8387065894608, 37.06699779260753, 9], [126.84606088258417, 37.06672832706917, 10], [126.84960718262685, 37.070174985483625, 11], [126.85444990852619, 37.06046761130322, 12], [126.85553592453233, 37.05699083922621, 13], [126.85635420651882, 37.052369373371995, 14], [126.85463875277742, 37.04998844617861, 15], [126.85204329143367, 37.04176370530994, 16], [126.84662056554762, 37.037944216429445, 17], [126.8440176576777, 37.037963591237336, 18], [126.84324898240689, 37.03464663511071, 19], [126.84387252551556, 37.03748583211465, 20], [126.84663076618716, 37.03780508613006, 21], [126.85212786490005, 37.041628643783056, 22], [126.85465025479915, 37.0498533003424, 23], [126.85642165892156, 37.0523694559248, 24], [126.85560331205141, 37.05702696472576, 25], [126.85453942013265, 37.06069298855781, 26], [126.8495169014274, 37.07033706130232, 27], [126.84591452407986, 37.066818241654104, 28], [126.83885251431339, 37.06711513109574, 29], [126.83809787466195, 37.0677087963154, 30], [126.83772311165343, 37.06942931155262, 31], [126.83409318797258, 37.073596167921814, 32], [126.83047144100027, 37.07895232384016, 33], [126.82832808542899, 37.08185964408305, 34], [126.82652726234878, 37.08591491286393, 35], [126.8210099396857, 37.08845823048677, 36], [126.81665334666609, 37.08874406473381, 37], [126.81582783195088, 37.082250988510175, 38]]}],
#     'id' : 'TripsLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': ({object, x, y}) => {
#         const tooltip = null
#     },
#     //'onClick' : null,
#     //'onDragStart' : null,
#     //'onDrag' : null,
#     //'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# }),new deck.GridCellLayer({
#     // GridCellLayer Added.
#     extruded: true,
#     cellSize: 100,
#     coverage: 1,
#     elevationScale: 1,
#     getPosition: obj => obj.coordinates,
#     getColor: [255, 0, 255, 255],
#     getElevation: 1000,
#
#     // MapLayer (inherited)
#     'data' : [{'coordinates': [126.81561169069604, 37.08218248972286], 'values': 66}, {'coordinates': [126.82831786376109, 37.08140909828359], 'values': 23}, {'coordinates': [126.8387065894608, 37.06699779260753], 'values': 58}, {'coordinates': [126.84606088258417, 37.06672832706917], 'values': 39}, {'coordinates': [126.84662056554762, 37.037944216429445], 'values': 95}, {'coordinates': [126.8440176576777, 37.037963591237336], 'values': 5}, {'coordinates': [126.84591452407986, 37.066818241654104], 'values': 6}, {'coordinates': [126.83047144100027, 37.07895232384016], 'values': 39}, {'coordinates': [126.81582783195088, 37.082250988510175], 'values': 26}],
#     'id' : 'GridCellLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': ({object, x, y}) => {
#         const tooltip = null
#     },
#     'onClick' : null,
#     'onDragStart' : null,
#     'onDrag' : null,
#     'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# }),]
#     })
#
#
#
#
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## CPUGrid Layer (Not Supported Yet.)

# %%
data = [
    {'coordinates': [37.524071, 127.02179]},
    {'coordinates': [37.505581, 127.024277]},
    {'coordinates': [37.511517, 127.021477]},
    {'coordinates': [37.512527, 127.035835]},
    {'coordinates': [37.520641, 127.034508]},
    {'coordinates': [37.527122, 127.02871699999999]},
    {'coordinates': [37.528614000000005, 127.038559]},
    {'coordinates': [37.529301000000004, 127.035599]},
    {'coordinates': [37.518902000000004, 127.04938500000002]},
    {'coordinates': [37.523613, 127.040176]}
]

# %%
m = Layer.Map(**view_options)
CPU_grid_layer = Layer.CPUGridLayer(data)
m.add(CPU_grid_layer)
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.0.0/dist.min.js'></script>
#
#     <!-- only if base map is needed -->
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v0.44.1/mapbox-gl.css' rel='stylesheet' />
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#     const deckgl = new deck.DeckGL({
#
#         container: 'container',
#         mapboxApiAccessToken: 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw',
#         latitude: 37.17407153,
#         longitude: 126.9086032,
#         zoom: 10,
#         bearing: 0,
#         pitch: 60,
#         mapStyle: 'mapbox://styles/mapbox/light-v9',
#         layers: [new deck.CPUGridLayer({
#     id: 'CPUGridLayer',
#     gpuAggregation: true,
#     data: [{'coordinates': [37.524071, 127.02179]}, {'coordinates': [37.505581, 127.024277]}, {'coordinates': [37.511517, 127.021477]}, {'coordinates': [37.512527, 127.035835]}, {'coordinates': [37.520641, 127.034508]}, {'coordinates': [37.527122, 127.02871699999999]}, {'coordinates': [37.528614000000005, 127.038559]}, {'coordinates': [37.529301000000004, 127.035599]}, {'coordinates': [37.518902000000004, 127.04938500000002]}, {'coordinates': [37.523613, 127.040176]}],
#     extruded: true,
#     cellSize: 1000,
#     elevationScale: 1,
#     getPosition: d => d.coordinates,
#
#     // MapLayer (inherited)
#     'data' : [{'coordinates': [37.524071, 127.02179]}, {'coordinates': [37.505581, 127.024277]}, {'coordinates': [37.511517, 127.021477]}, {'coordinates': [37.512527, 127.035835]}, {'coordinates': [37.520641, 127.034508]}, {'coordinates': [37.527122, 127.02871699999999]}, {'coordinates': [37.528614000000005, 127.038559]}, {'coordinates': [37.529301000000004, 127.035599]}, {'coordinates': [37.518902000000004, 127.04938500000002]}, {'coordinates': [37.523613, 127.040176]}],
#     'id' : 'CPUGridLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': ({object, x, y}) => {
#         const tooltip = null
#     },
#     'onClick' : null,
#     'onDragStart' : null,
#     'onDrag' : null,
#     'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# }),]
#     })
#
#
#
#
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-d2da3ba4e487> in <module>
# ----> 1 m.show()
#
# ~/Desktop/dev/deckgl_jupyter/Layer.py in show(self, **kwargs)
#      98     def show(self, **kwargs):
#      99         # Load the HTML iframe
# --> 100         html = self.create_html(**kwargs)
#     101         map_html = self.as_iframe(html)
#     102
#
# ~/Desktop/dev/deckgl_jupyter/Layer.py in create_html(self, filename)
#      82         layer_html = ''
#      83         for layer in self.layers:
# ---> 84             layer_options = layer.get_options()
#      85             layer_options = self.make_str(layer_options)
#      86             html = templates.format(layer.template, **layer_options)
#
# ~/Desktop/dev/deckgl_jupyter/Layer.py in get_options(self)
#     438         return dict(
#     439             data=self.data,
# --> 440             id=self.id,
#     441             cellSize=self.cellSize,
#     442             colorRange=self.colorRange,
#
# AttributeError: 'CPUGridLayer' object has no attribute 'id'
