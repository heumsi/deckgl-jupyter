# %% [markdown]
# # Layer Examples

# %%
import os

from deckgljupyter import Layer
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
access_token = os.getenv('MAPBOX_ACCESS_TOKEN')
view_options = {
    'center': [126.9086032, 37.17407153],
    'zoom': 10,
    'bearing': 0,
    'pitch': 60,
    'height': '700px',
    'style': 'mapbox://styles/mapbox/light-v9',
    'access_token': access_token,
}

# %% [markdown]
# ## Polygon Layer

# %%
Layer.PolygonLayer?

# %%
data = [{
    "polygon": [[126.908, 37.174, 0], [126.986, 37.541, 0], [127.179, 37.245, 0], [126.908, 37.174, 0]],
    "color": [255, 120, 0]
}]

# %%
m = Layer.Map(**view_options)
polygon_layer = Layer.PolygonLayer(data,
                                   getFillColor='obj => obj.color')
m.add(polygon_layer)
m.show()
# Out:
# ---------------------------------------------------------------------------
# TemplateNotFound                          Traceback (most recent call last)
# <ipython-input-4-b27d0b92d241> in <module>
#       3                                    getFillColor='obj => obj.color')
#       4 m.add(polygon_layer)
# ----> 5 m.show()
#
# ~/anaconda3/envs/test/lib/python3.6/site-packages/deckgljupyter/Layer.py in show(self, **kwargs)
#     112     def show(self, **kwargs):
#     113         # Load the HTML iframe
# --> 114         html = self.create_html(**kwargs)
#     115         map_html = self.as_iframe(html)
#     116
#
# ~/anaconda3/envs/test/lib/python3.6/site-packages/deckgljupyter/Layer.py in create_html(self, buildings, filename)
#      97             layer_options = layer.get_options()
#      98             layer_options = self.make_str(layer_options)
# ---> 99             html = templates.format(layer.template, **layer_options)
#     100             layers.append(html)
#     101
#
# ~/anaconda3/envs/test/lib/python3.6/site-packages/deckgljupyter/templates.py in format(template_name, **kwargs)
#       9
#      10 def format(template_name, **kwargs):
# ---> 11     template = env.get_template('{}.html'.format(template_name))
#      12     return template.render(**kwargs)
#
# ~/anaconda3/envs/test/lib/python3.6/site-packages/jinja2/environment.py in get_template(self, name, parent, globals)
#     828         if parent is not None:
#     829             name = self.join_path(name, parent)
# --> 830         return self._load_template(name, self.make_globals(globals))
#     831
#     832     @internalcode
#
# ~/anaconda3/envs/test/lib/python3.6/site-packages/jinja2/environment.py in _load_template(self, name, globals)
#     802                                          template.is_up_to_date):
#     803                 return template
# --> 804         template = self.loader.load(self, name, globals)
#     805         if self.cache is not None:
#     806             self.cache[cache_key] = template
#
# ~/anaconda3/envs/test/lib/python3.6/site-packages/jinja2/loaders.py in load(self, environment, name, globals)
#     111         # first we try to get the source for this template together
#     112         # with the filename and the uptodate function.
# --> 113         source, filename, uptodate = self.get_source(environment, name)
#     114
#     115         # try to load the code from the bytecode cache if there is a
#
# ~/anaconda3/envs/test/lib/python3.6/site-packages/jinja2/loaders.py in get_source(self, environment, template)
#     185                     return False
#     186             return contents, filename, uptodate
# --> 187         raise TemplateNotFound(template)
#     188
#     189     def list_templates(self):
#
# TemplateNotFound: PolygonLayer.html

# %% [markdown]
# ## Arc Layer

# %%
Layer.ArcLayer?

# %%
data = [
    {
        'name': 'Hwaseong - Seoul',
        'sourcePosition': [126.908, 37.174],
        'targetPosition': [126.986, 37.541],
    },
    {
        'name': 'Seoul-Suwon',
        'sourcePosition': [126.986, 37.541],
        'targetPosition': [127.179, 37.245]
    }
]

# %%
m = Layer.Map(**view_options)
arc_layer = Layer.ArcLayer(data,
                           pickable=True,
                           getWidth=10,
                           tooltip = ["name"])
m.add(arc_layer)
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@7.2.0/dist.min.js'></script>
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.css' rel='stylesheet' />
#     <script src='https://api.mapbox.com/mapbox-gl-js/plugins/mapbox-gl-language/v0.10.1/mapbox-gl-language.js'></script>
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#
#         #tooltip {
#             position: absolute;
#             z-index: 1;
#             pointer-events: none;
#             background-color: white;
#             border-radius: 10%;
#             padding: 10px;
#             font-size:12px;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
#     <div id='tooltip' id='tooltip'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#
#     const {MapboxLayer} = deck;
#     mapboxgl.accessToken = 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw';
#
#     const map = new mapboxgl.Map({
#         container: 'container',
#         style: 'mapbox://styles/mapbox/light-v9',
#         center: [126.9086032, 37.17407153],
#         zoom: 10,
#         pitch: 60,
#         bearing: 0
#     });
#
#     map.on('load', () => {
#
#
#
#
#             map.addLayer(new MapboxLayer(
#                 {
#     'type': ArcLayer,
#
#     // ArcLayer Added.
#     'widthUnits': 'pixels',
#     'widthScale': 1,
#     'widthMinPixels': 0,
#     'widthMaxPixels': 9007199254740991,
#     'getSourcePosition': object => object.sourcePosition,
#     'getTargetPosition': object => object.targetPosition,
#     'getSourceColor': [0, 0, 0, 255],
#     'getTargetColor': [0, 0, 0, 255],
#     'getWidth': 10,
#     'getHeight': 1,
#     'getTilt': 0,
#
#     // BaseLayer (inherited)
#     'data' : [{'name': 'Hwaseong - Seoul', 'sourcePosition': [126.908, 37.174], 'targetPosition': [126.986, 37.541]}, {'name': 'Seoul-Suwon', 'sourcePosition': [126.986, 37.541], 'targetPosition': [127.179, 37.245]}],
#     'id' : 'deckgl-arc',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : true,
#     'onHover': info => setTooltip(info.object, info.x, info.y, ['name']),
#     //'onClick' : null,
#     //'onDragStart' : null,
#     //'onDrag' : null,
#     //'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# }
#
#             ));
#
#     });
#
#     var language = new MapboxLanguage({
#         defaultLanguage: 'ko'
#     });
#     map.addControl(language);
#
#
#
#
#     function setTooltip(object, x, y, tooltip) {
#         const el = document.getElementById('tooltip');
#
#         if (object) {
#             str_tooltip = '';
#             for (var i in tooltip) {
#                 item = tooltip[i]
#                 str_tooltip += item + ': ' + object[item] + '\n'
#             }
#             el.innerHTML = str_tooltip
#             el.style.display = 'block';
#             el.style.left = x + 'px';
#             el.style.top = y + 'px';
#         } else {
#             el.style.display = 'none';
#         }
#     }
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## Path Layer

# %%
Layer.PathLayer?

# %%
data = [
    {
        'path': [[126.986, 37.541], [126.9086032, 37.17407153]],
        'name': 'Seoul-Hwaseong',
        'color': [255, 30, 100]
    },
    {
        'path': [[126.986, 37.541], [127.179108, 37.245635]],
        'name': 'Seoul-Suwon',
        'color': [200, 100, 30]
    }
]

# %%
m = Layer.Map(**view_options)
path_layer = Layer.PathLayer(data, 
                             getWidth=10,
                             widthScale=50,
                             getColor='obj => obj.color')
m.add(path_layer)
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.2.0/dist.min.js'></script>
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.css' rel='stylesheet' />
#     <script src='https://api.mapbox.com/mapbox-gl-js/plugins/mapbox-gl-language/v0.10.1/mapbox-gl-language.js'></script>
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#
#         #tooltip {
#             position: absolute;
#             z-index: 1;
#             pointer-events: none;
#             background-color: white;
#             border-radius: 10%;
#             padding: 10px;
#             font-size:12px;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
#     <div id='tooltip' id='tooltip'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#
#     const {MapboxLayer, ArcLayer} = deck;
#     mapboxgl.accessToken = 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw';
#
#     const map = new mapboxgl.Map({
#         container: 'container',
#         style: 'mapbox://styles/mapbox/light-v9',
#         center: [126.9086032, 37.17407153],
#         zoom: 10,
#         pitch: 60,
#         bearing: 0
#     });
#
#     map.on('load', () => {
#
#         const firstLabelLayerId = map.getStyle().layers.find(layer => layer.type === 'symbol').id;
#
#
#
#
#             map.addLayer(new MapboxLayer(
#                 {
#     'type': PathLayer,
#
#     // PathLayer Added.
#     'widthUnits': 1,
#     'widthScale': 50,
#     'widthMinPixels': 0,
#     'widthMaxPixels': 9007199254740991,
#     'rounded': false,
#     'billboard': false,
#     'miterLimit': 4,
#     'getPath': object => object.path,
#     'getColor': obj => obj.color,
#     'getWidth': 10,
#     'dashJustified': false,
#
#     // BaseLayer (inherited)
#     'data' : [{'path': [[126.986, 37.541], [126.9086032, 37.17407153]], 'name': 'Seoul-Hwaseong', 'color': [255, 30, 100]}, {'path': [[126.986, 37.541], [127.179108, 37.245635]], 'name': 'Seoul-Suwon', 'color': [200, 100, 30]}],
#     'id' : 'PathLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': info => setTooltip(info.object, info.x, info.y, null),
#     //'onClick' : null,
#     //'onDragStart' : null,
#     //'onDrag' : null,
#     //'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# }
#             ));
#
#     });
#
#     var language = new MapboxLanguage({
#         defaultLanguage: 'ko'
#     });
#     map.addControl(language);
#
#
#
#
#     function setTooltip(object, x, y, tooltip) {
#         const el = document.getElementById('tooltip');
#
#         if (object) {
#             str_tooltip = '';
#             for (var i in tooltip) {
#                 item = tooltip[i]
#                 str_tooltip += item + ': ' + object[item] + '\n'
#             }
#             el.innerHTML = str_tooltip
#             el.style.display = 'block';
#             el.style.left = x + 'px';
#             el.style.top = y + 'px';
#         } else {
#             el.style.display = 'none';
#         }
#     }
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## Trips Layer

# %%
Layer.TripsLayer?

# %%
trips = [
    {'name': 'bus',
    'color': [255, 30, 100],
    'path': [
        [126.81561169069604, 37.08218248972286, 0],
        [126.81694879927656, 37.08192703057454, 1],
        [126.82058506532772, 37.08345425470472, 2],
        [126.82642187278732, 37.08594720874324, 3],
        [126.82831786376109, 37.08140909828359, 4],
        [126.83028046191004, 37.07886194207198, 5],
        [126.83399231816769, 37.0734428447721, 6],
        [126.83761076282099, 37.069384103175935, 7],
        [126.83795179514074, 37.067663541757256, 8],
        [126.8387065894608, 37.06699779260753, 9],
        [126.84606088258417, 37.06672832706917, 10],
        [126.84960718262685, 37.070174985483625, 11],
        [126.85444990852619, 37.06046761130322, 12],
        [126.85553592453233, 37.05699083922621, 13],
        [126.85635420651882, 37.052369373371995, 14],
        [126.85463875277742, 37.04998844617861, 15],
        [126.85204329143367, 37.04176370530994, 16],
        [126.84662056554762, 37.037944216429445, 17],
        [126.8440176576777, 37.037963591237336, 18],
        [126.84324898240689, 37.03464663511071, 19],
        [126.84387252551556, 37.03748583211465, 20],
        [126.84663076618716, 37.03780508613006, 21],
        [126.85212786490005, 37.041628643783056, 22],
        [126.85465025479915, 37.0498533003424, 23],
        [126.85642165892156, 37.0523694559248, 24],
        [126.85560331205141, 37.05702696472576, 25],
        [126.85453942013265, 37.06069298855781, 26],
        [126.8495169014274, 37.07033706130232, 27],
        [126.84591452407986, 37.066818241654104, 28],
        [126.83885251431339, 37.06711513109574, 29],
        [126.83809787466195, 37.0677087963154, 30],
        [126.83772311165343, 37.06942931155262, 31],
        [126.83409318797258, 37.073596167921814, 32],
        [126.83047144100027, 37.07895232384016, 33],
        [126.82832808542899, 37.08185964408305, 34],
        [126.82652726234878, 37.08591491286393, 35],
        [126.8210099396857, 37.08845823048677, 36],
        [126.81665334666609, 37.08874406473381, 37],
        [126.81582783195088, 37.082250988510175, 38]]
    }
]

view_options['center'] = [126.81561169069604, 37.08218248972286]
view_options['zoom'] = 12

# %%
m = Layer.Map(**view_options)
trip_layer = Layer.TripsLayer(trips, 
                             getWidth=5,
                             getColor='obj => obj.color',
                             widthScale=20,
                             widthMinPixels=2,
                             currentTime=20,
                             rounded=True)
m.add(trip_layer)
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.2.0/dist.min.js'></script>
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.css' rel='stylesheet' />
#     <script src='https://api.mapbox.com/mapbox-gl-js/plugins/mapbox-gl-language/v0.10.1/mapbox-gl-language.js'></script>
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#
#         #tooltip {
#             position: absolute;
#             z-index: 1;
#             pointer-events: none;
#             background-color: white;
#             border-radius: 10%;
#             padding: 10px;
#             font-size:12px;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
#     <div id='tooltip' id='tooltip'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#
#     const {MapboxLayer} = deck;
#     mapboxgl.accessToken = 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw';
#
#     const map = new mapboxgl.Map({
#         container: 'container',
#         style: 'mapbox://styles/mapbox/light-v9',
#         center: [126.81561169069604, 37.08218248972286],
#         zoom: 12,
#         pitch: 60,
#         bearing: 0
#     });
#
#     map.on('load', () => {
#
#
#
#
#             map.addLayer(new MapboxLayer(
#                 {
#     'type': TripsLayer,
#
#     // TripsLayer Added.
#     'trailLength': 120,
#     'currentTime': 20,
#
#     // PathLayer (inherited)
#     'widthScale': 20,
#     'widthMinPixels': 2,
#     'widthMaxPixels': 9007199254740991,
#     'rounded': true,
#     'billboard': false,
#     'miterLimit': 4,
#     'dashJustified': false,
#
#     'getPath': object => object.path,
#     'getColor': obj => obj.color,
#     'getWidth': 5,
#
#     // BaseLayer (inherited)
#     'data' : [{'name': 'bus', 'color': [255, 30, 100], 'path': [[126.81561169069604, 37.08218248972286, 0], [126.81694879927656, 37.08192703057454, 1], [126.82058506532772, 37.08345425470472, 2], [126.82642187278732, 37.08594720874324, 3], [126.82831786376109, 37.08140909828359, 4], [126.83028046191004, 37.07886194207198, 5], [126.83399231816769, 37.0734428447721, 6], [126.83761076282099, 37.069384103175935, 7], [126.83795179514074, 37.067663541757256, 8], [126.8387065894608, 37.06699779260753, 9], [126.84606088258417, 37.06672832706917, 10], [126.84960718262685, 37.070174985483625, 11], [126.85444990852619, 37.06046761130322, 12], [126.85553592453233, 37.05699083922621, 13], [126.85635420651882, 37.052369373371995, 14], [126.85463875277742, 37.04998844617861, 15], [126.85204329143367, 37.04176370530994, 16], [126.84662056554762, 37.037944216429445, 17], [126.8440176576777, 37.037963591237336, 18], [126.84324898240689, 37.03464663511071, 19], [126.84387252551556, 37.03748583211465, 20], [126.84663076618716, 37.03780508613006, 21], [126.85212786490005, 37.041628643783056, 22], [126.85465025479915, 37.0498533003424, 23], [126.85642165892156, 37.0523694559248, 24], [126.85560331205141, 37.05702696472576, 25], [126.85453942013265, 37.06069298855781, 26], [126.8495169014274, 37.07033706130232, 27], [126.84591452407986, 37.066818241654104, 28], [126.83885251431339, 37.06711513109574, 29], [126.83809787466195, 37.0677087963154, 30], [126.83772311165343, 37.06942931155262, 31], [126.83409318797258, 37.073596167921814, 32], [126.83047144100027, 37.07895232384016, 33], [126.82832808542899, 37.08185964408305, 34], [126.82652726234878, 37.08591491286393, 35], [126.8210099396857, 37.08845823048677, 36], [126.81665334666609, 37.08874406473381, 37], [126.81582783195088, 37.082250988510175, 38]]}],
#     'id' : 'TripsLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': info => setTooltip(info.object, info.x, info.y, null),
#     //'onClick' : null,
#     //'onDragStart' : null,
#     //'onDrag' : null,
#     //'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# }
#             ));
#
#     });
#
#     var language = new MapboxLanguage({
#         defaultLanguage: 'ko'
#     });
#     map.addControl(language);
#
#
#
#
#     function setTooltip(object, x, y, tooltip) {
#         const el = document.getElementById('tooltip');
#
#         if (object) {
#             str_tooltip = '';
#             for (var i in tooltip) {
#                 item = tooltip[i]
#                 str_tooltip += item + ': ' + object[item] + '\n'
#             }
#             el.innerHTML = str_tooltip
#             el.style.display = 'block';
#             el.style.left = x + 'px';
#             el.style.top = y + 'px';
#         } else {
#             el.style.display = 'none';
#         }
#     }
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## Scatterplot Layer

# %%
Layer.ScatterplotLayer?
# Out:
# Init signature:
# Layer.ScatterplotLayer(
#     data,
#     id='ScatterplotLayer',
#     radiusScale=1,
#     lineWidthUnits='meters',
#     lineWdithScale=1,
#     stroked=False,
#     filled=True,
#     radiusMinPixels=0,
#     radiusMaxPixels=0,
#     lineWidthMinPixels=0,
#     lineWidthMaxPixels=9007199254740991,
#     getPosition='object => object.position',
#     getRadius=1,
#     getColor=[0, 0, 0, 255],
#     getFillColor=[255, 140, 0],
#     getLineColor=[0, 0, 0],
#     getLineWidth=1,
#     *args,
#     **kwargs,
# )
# Docstring:      <no docstring>
# File:           ~/Desktop/dev/deckgl_jupyter/Layer.py
# Type:           type
# Subclasses:

# %%
data = [
    {
        'name': 'Seoul',
        'coordinates': [126.986, 37.541]
    },
    {
        'name': 'Suwon',
        'coordinates': [126.908, 37.174]
    }
]

# %%
m = Layer.Map(**view_options)
scatterplot_Layer = Layer.ScatterplotLayer(data, 
                                           getRadius=500,
                                           lineWidthUnits='kilometers',
                                           getFillColor=[255,232,0],
                                           getPosition='obj => obj.coordinates')
m.add(scatterplot_Layer)
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@7.2.0/dist.min.js'></script>
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.css' rel='stylesheet' />
#     <script src='https://api.mapbox.com/mapbox-gl-js/plugins/mapbox-gl-language/v0.10.1/mapbox-gl-language.js'></script>
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#
#         #tooltip {
#             position: absolute;
#             z-index: 1;
#             pointer-events: none;
#             background-color: white;
#             border-radius: 10%;
#             padding: 10px;
#             font-size:12px;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
#     <div id='tooltip' id='tooltip'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#
#     const {MapboxLayer} = deck;
#     mapboxgl.accessToken = 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw';
#
#     const map = new mapboxgl.Map({
#         container: 'container',
#         style: 'mapbox://styles/mapbox/light-v9',
#         center: [126.9086032, 37.17407153],
#         zoom: 10,
#         pitch: 60,
#         bearing: 0
#     });
#
#     map.on('load', () => {
#
#
#
#
#             map.addLayer(new MapboxLayer(
#                 {
#     'type': ScatterplotLayer,
#
#     // ScatterplotLayer Added.
#     'radiusScale': 1,
#     'lineWidthUnits': 'kilometers',
#     'lineWdithScale': 1,
#     'stroked': false,
#     'filled': true,
#     'radiusMinPixels': 0,
#     'radiusMaxPixels': 0,
#     'lineWidthMinPixels': 0,
#     'lineWidthMaxPixels': 9007199254740991,
#     'getPosition': obj => obj.coordinates,
#     'getRadius': 500,
#     'getColor': [0, 0, 0, 255],
#     'getFillColor': [255, 232, 0],
#     'getLineColor': [0, 0, 0],
#     'getLineWidth': 1,
#
#     // BaseLayer (inherited)
#     'data' : [{'name': 'Seoul', 'coordinates': [126.986, 37.541]}, {'name': 'Suwon', 'coordinates': [126.908, 37.174]}],
#     'id' : 'ScatterplotLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': info => setTooltip(info.object, info.x, info.y, null),
#     'onClick' : null,
#     'onDragStart' : null,
#     'onDrag' : null,
#     'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# }
#             ));
#
#     });
#
#     var language = new MapboxLanguage({
#         defaultLanguage: 'ko'
#     });
#     map.addControl(language);
#
#
#
#
#     function setTooltip(object, x, y, tooltip) {
#         const el = document.getElementById('tooltip');
#
#         if (object) {
#             str_tooltip = '';
#             for (var i in tooltip) {
#                 item = tooltip[i]
#                 str_tooltip += item + ': ' + object[item] + '\n'
#             }
#             el.innerHTML = str_tooltip
#             el.style.display = 'block';
#             el.style.left = x + 'px';
#             el.style.top = y + 'px';
#         } else {
#             el.style.display = 'none';
#         }
#     }
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## GridCell Layer

# %%
Layer.GridCellLayer?
# Out:
# Init signature:
# Layer.GridCellLayer(
#     data,
#     id='GridCellLayer',
#     cellSize=1000,
#     coverage=1,
#     elevationScale=1,
#     extruded=True,
#     getPosition='x => x.position',
#     getColor=[255, 0, 255, 255],
#     getElevation=1000,
#     *args,
#     **kwargs,
# )
# Docstring:      <no docstring>
# File:           ~/Desktop/dev/deckgl_jupyter/Layer.py
# Type:           type
# Subclasses:

# %%
data = [
    {'coordinates': [126.81561169069604, 37.08218248972286], 'values': 66},
    {'coordinates': [126.82831786376109, 37.08140909828359], 'values': 23},
    {'coordinates': [126.8387065894608, 37.06699779260753], 'values': 58},
    {'coordinates': [126.84606088258417, 37.06672832706917], 'values': 39},
    {'coordinates': [126.84662056554762, 37.037944216429445], 'values': 95},
    {'coordinates': [126.8440176576777, 37.037963591237336], 'values': 5},
    {'coordinates': [126.84591452407986, 37.066818241654104], 'values': 6},
    {'coordinates': [126.83047144100027, 37.07895232384016], 'values': 39},
    {'coordinates': [126.81582783195088, 37.082250988510175], 'values': 26}
]

# %%
m = Layer.Map(**view_options)
GC_layer = Layer.GridCellLayer(data,
                               cellSize=100,
                               getPosition='obj => obj.coordinates')
m.add(GC_layer)
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.2.0/dist.min.js'></script>
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.css' rel='stylesheet' />
#     <script src='https://api.mapbox.com/mapbox-gl-js/plugins/mapbox-gl-language/v0.10.1/mapbox-gl-language.js'></script>
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#
#         #tooltip {
#             position: absolute;
#             z-index: 1;
#             pointer-events: none;
#             background-color: white;
#             border-radius: 10%;
#             padding: 10px;
#             font-size:12px;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
#     <div id='tooltip' id='tooltip'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#
#     const {MapboxLayer} = deck;
#     mapboxgl.accessToken = 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw';
#
#     const map = new mapboxgl.Map({
#         container: 'container',
#         style: 'mapbox://styles/mapbox/light-v9',
#         center: [126.81561169069604, 37.08218248972286],
#         zoom: 12,
#         pitch: 60,
#         bearing: 0
#     });
#
#     map.on('load', () => {
#
#
#
#
#             map.addLayer(new MapboxLayer(
#                 {
#     type: GridCellLayer,
#
#     // GridCellLayer Added.
#     extruded: true,
#     cellSize: 100,
#     coverage: 1,
#     elevationScale: 1,
#     getPosition: obj => obj.coordinates,
#     getColor: [255, 0, 255, 255],
#     getElevation: 1000,
#
#     // MapLayer (inherited)
#     'data' : [{'coordinates': [126.81561169069604, 37.08218248972286], 'values': 66}, {'coordinates': [126.82831786376109, 37.08140909828359], 'values': 23}, {'coordinates': [126.8387065894608, 37.06699779260753], 'values': 58}, {'coordinates': [126.84606088258417, 37.06672832706917], 'values': 39}, {'coordinates': [126.84662056554762, 37.037944216429445], 'values': 95}, {'coordinates': [126.8440176576777, 37.037963591237336], 'values': 5}, {'coordinates': [126.84591452407986, 37.066818241654104], 'values': 6}, {'coordinates': [126.83047144100027, 37.07895232384016], 'values': 39}, {'coordinates': [126.81582783195088, 37.082250988510175], 'values': 26}],
#     'id' : 'GridCellLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': info => setTooltip(info.object, info.x, info.y, null),
#     'onClick' : null,
#     'onDragStart' : null,
#     'onDrag' : null,
#     'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# }
#             ));
#
#     });
#
#     var language = new MapboxLanguage({
#         defaultLanguage: 'ko'
#     });
#     map.addControl(language);
#
#
#
#
#     function setTooltip(object, x, y, tooltip) {
#         const el = document.getElementById('tooltip');
#
#         if (object) {
#             str_tooltip = '';
#             for (var i in tooltip) {
#                 item = tooltip[i]
#                 str_tooltip += item + ': ' + object[item] + '\n'
#             }
#             el.innerHTML = str_tooltip
#             el.style.display = 'block';
#             el.style.left = x + 'px';
#             el.style.top = y + 'px';
#         } else {
#             el.style.display = 'none';
#         }
#     }
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## Overay Layers

# %%
m = Layer.Map(**view_options)
m.add(trip_layer)
m.add(GC_layer)
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.2.0/dist.min.js'></script>
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.css' rel='stylesheet' />
#     <script src='https://api.mapbox.com/mapbox-gl-js/plugins/mapbox-gl-language/v0.10.1/mapbox-gl-language.js'></script>
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#
#         #tooltip {
#             position: absolute;
#             z-index: 1;
#             pointer-events: none;
#             background-color: white;
#             border-radius: 10%;
#             padding: 10px;
#             font-size:12px;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
#     <div id='tooltip' id='tooltip'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#
#     const {MapboxLayer} = deck;
#     mapboxgl.accessToken = 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw';
#
#     const map = new mapboxgl.Map({
#         container: 'container',
#         style: 'mapbox://styles/mapbox/light-v9',
#         center: [126.81561169069604, 37.08218248972286],
#         zoom: 12,
#         pitch: 60,
#         bearing: 0
#     });
#
#     map.on('load', () => {
#
#
#
#
#             map.addLayer(new MapboxLayer(
#                 {
#     'type': TripsLayer,
#
#     // TripsLayer Added.
#     'trailLength': 120,
#     'currentTime': 20,
#
#     // PathLayer (inherited)
#     'widthScale': 20,
#     'widthMinPixels': 2,
#     'widthMaxPixels': 9007199254740991,
#     'rounded': true,
#     'billboard': false,
#     'miterLimit': 4,
#     'dashJustified': false,
#
#     'getPath': object => object.path,
#     'getColor': obj => obj.color,
#     'getWidth': 5,
#
#     // BaseLayer (inherited)
#     'data' : [{'name': 'bus', 'color': [255, 30, 100], 'path': [[126.81561169069604, 37.08218248972286, 0], [126.81694879927656, 37.08192703057454, 1], [126.82058506532772, 37.08345425470472, 2], [126.82642187278732, 37.08594720874324, 3], [126.82831786376109, 37.08140909828359, 4], [126.83028046191004, 37.07886194207198, 5], [126.83399231816769, 37.0734428447721, 6], [126.83761076282099, 37.069384103175935, 7], [126.83795179514074, 37.067663541757256, 8], [126.8387065894608, 37.06699779260753, 9], [126.84606088258417, 37.06672832706917, 10], [126.84960718262685, 37.070174985483625, 11], [126.85444990852619, 37.06046761130322, 12], [126.85553592453233, 37.05699083922621, 13], [126.85635420651882, 37.052369373371995, 14], [126.85463875277742, 37.04998844617861, 15], [126.85204329143367, 37.04176370530994, 16], [126.84662056554762, 37.037944216429445, 17], [126.8440176576777, 37.037963591237336, 18], [126.84324898240689, 37.03464663511071, 19], [126.84387252551556, 37.03748583211465, 20], [126.84663076618716, 37.03780508613006, 21], [126.85212786490005, 37.041628643783056, 22], [126.85465025479915, 37.0498533003424, 23], [126.85642165892156, 37.0523694559248, 24], [126.85560331205141, 37.05702696472576, 25], [126.85453942013265, 37.06069298855781, 26], [126.8495169014274, 37.07033706130232, 27], [126.84591452407986, 37.066818241654104, 28], [126.83885251431339, 37.06711513109574, 29], [126.83809787466195, 37.0677087963154, 30], [126.83772311165343, 37.06942931155262, 31], [126.83409318797258, 37.073596167921814, 32], [126.83047144100027, 37.07895232384016, 33], [126.82832808542899, 37.08185964408305, 34], [126.82652726234878, 37.08591491286393, 35], [126.8210099396857, 37.08845823048677, 36], [126.81665334666609, 37.08874406473381, 37], [126.81582783195088, 37.082250988510175, 38]]}],
#     'id' : 'TripsLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': info => setTooltip(info.object, info.x, info.y, null),
#     //'onClick' : null,
#     //'onDragStart' : null,
#     //'onDrag' : null,
#     //'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# }
#             ));
#
#             map.addLayer(new MapboxLayer(
#                 {
#     type: GridCellLayer,
#
#     // GridCellLayer Added.
#     extruded: true,
#     cellSize: 100,
#     coverage: 1,
#     elevationScale: 1,
#     getPosition: obj => obj.coordinates,
#     getColor: [255, 0, 255, 255],
#     getElevation: 1000,
#
#     // MapLayer (inherited)
#     'data' : [{'coordinates': [126.81561169069604, 37.08218248972286], 'values': 66}, {'coordinates': [126.82831786376109, 37.08140909828359], 'values': 23}, {'coordinates': [126.8387065894608, 37.06699779260753], 'values': 58}, {'coordinates': [126.84606088258417, 37.06672832706917], 'values': 39}, {'coordinates': [126.84662056554762, 37.037944216429445], 'values': 95}, {'coordinates': [126.8440176576777, 37.037963591237336], 'values': 5}, {'coordinates': [126.84591452407986, 37.066818241654104], 'values': 6}, {'coordinates': [126.83047144100027, 37.07895232384016], 'values': 39}, {'coordinates': [126.81582783195088, 37.082250988510175], 'values': 26}],
#     'id' : 'GridCellLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': info => setTooltip(info.object, info.x, info.y, null),
#     'onClick' : null,
#     'onDragStart' : null,
#     'onDrag' : null,
#     'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# }
#             ));
#
#     });
#
#     var language = new MapboxLanguage({
#         defaultLanguage: 'ko'
#     });
#     map.addControl(language);
#
#
#
#
#     function setTooltip(object, x, y, tooltip) {
#         const el = document.getElementById('tooltip');
#
#         if (object) {
#             str_tooltip = '';
#             for (var i in tooltip) {
#                 item = tooltip[i]
#                 str_tooltip += item + ': ' + object[item] + '\n'
#             }
#             el.innerHTML = str_tooltip
#             el.style.display = 'block';
#             el.style.left = x + 'px';
#             el.style.top = y + 'px';
#         } else {
#             el.style.display = 'none';
#         }
#     }
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## Heatmap Layer

# %%
data = [
    {'coordinates': [126.81561169069604, 37.08218248972286], 'values': 66},
    {'coordinates': [126.82831786376109, 37.08140909828359], 'values': 23},
    {'coordinates': [126.8387065894608, 37.06699779260753], 'values': 58},
    {'coordinates': [126.84606088258417, 37.06672832706917], 'values': 39},
    {'coordinates': [126.84662056554762, 37.037944216429445], 'values': 95},
    {'coordinates': [126.8440176576777, 37.037963591237336], 'values': 5},
    {'coordinates': [126.84591452407986, 37.066818241654104], 'values': 6},
    {'coordinates': [126.83047144100027, 37.07895232384016], 'values': 39},
    {'coordinates': [126.81582783195088, 37.082250988510175], 'values': 26}
]

# %%
m = Layer.Map(**view_options)
heatmap_layer = Layer.HeatmapLayer(data,
                                   getPosition='obj => obj.coordinates')
m.add(heatmap_layer)
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@7.2.0/dist.min.js'></script>
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.css' rel='stylesheet' />
#     <script src='https://api.mapbox.com/mapbox-gl-js/plugins/mapbox-gl-language/v0.10.1/mapbox-gl-language.js'></script>
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#
#         #tooltip {
#             position: absolute;
#             z-index: 1;
#             pointer-events: none;
#             background-color: white;
#             border-radius: 10%;
#             padding: 10px;
#             font-size:12px;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
#     <div id='tooltip' id='tooltip'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#
#     const {MapboxLayer} = deck;
#     mapboxgl.accessToken = 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw';
#
#     const map = new mapboxgl.Map({
#         container: 'container',
#         style: 'mapbox://styles/mapbox/light-v9',
#         center: [126.9086032, 37.17407153],
#         zoom: 10,
#         pitch: 60,
#         bearing: 0
#     });
#
#     map.on('load', () => {
#
#
#
#
#             map.addLayer(new MapboxLayer(
#                 {
#     type: HeatmapLayer,
#
#     // HeatmapLayer Added.
#     radiusPixels: 30,
#     colorRange: [[255, 255, 178], [254, 217, 118], [254, 178, 76], [253, 141, 60], [240, 59, 32], [189, 0, 38]],
#     intensity: 1,
#     threshold: 0.05,
#     getPosition: obj => obj.coordinates,
#     getWeight: 1,
#
#     // MapLayer (inherited)
#     'data' : [{'coordinates': [126.81561169069604, 37.08218248972286], 'values': 66}, {'coordinates': [126.82831786376109, 37.08140909828359], 'values': 23}, {'coordinates': [126.8387065894608, 37.06699779260753], 'values': 58}, {'coordinates': [126.84606088258417, 37.06672832706917], 'values': 39}, {'coordinates': [126.84662056554762, 37.037944216429445], 'values': 95}, {'coordinates': [126.8440176576777, 37.037963591237336], 'values': 5}, {'coordinates': [126.84591452407986, 37.066818241654104], 'values': 6}, {'coordinates': [126.83047144100027, 37.07895232384016], 'values': 39}, {'coordinates': [126.81582783195088, 37.082250988510175], 'values': 26}],
#     'id' : 'HeatmapLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': info => setTooltip(info.object, info.x, info.y, null),
#     'onClick' : null,
#     'onDragStart' : null,
#     'onDrag' : null,
#     'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# }
#             ));
#
#     });
#
#     var language = new MapboxLanguage({
#         defaultLanguage: 'ko'
#     });
#     map.addControl(language);
#
#
#
#
#     function setTooltip(object, x, y, tooltip) {
#         const el = document.getElementById('tooltip');
#
#         if (object) {
#             str_tooltip = '';
#             for (var i in tooltip) {
#                 item = tooltip[i]
#                 str_tooltip += item + ': ' + object[item] + '\n'
#             }
#             el.innerHTML = str_tooltip
#             el.style.display = 'block';
#             el.style.left = x + 'px';
#             el.style.top = y + 'px';
#         } else {
#             el.style.display = 'none';
#         }
#     }
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## CPUGrid Layer

# %%
data = [
    {'coordinates': [126.81561169069604, 37.08218248972286], 'values': 66},
    {'coordinates': [126.82831786376109, 37.08140909828359], 'values': 23},
    {'coordinates': [126.8387065894608, 37.06699779260753], 'values': 58},
    {'coordinates': [126.84606088258417, 37.06672832706917], 'values': 39},
    {'coordinates': [126.84662056554762, 37.037944216429445], 'values': 95},
    {'coordinates': [126.8440176576777, 37.037963591237336], 'values': 5},
    {'coordinates': [126.84591452407986, 37.066818241654104], 'values': 6},
    {'coordinates': [126.83047144100027, 37.07895232384016], 'values': 39},
    {'coordinates': [126.81582783195088, 37.082250988510175], 'values': 26}
]

# %%
m = Layer.Map(**view_options)
Grid_layer = Layer.GridLayer(data,
                            cellSize=200,
                            elevationScale=100,
                            getPosition='obj => obj.coordinates')
m.add(Grid_layer)
m.show()
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@~7.2.0/dist.min.js'></script>
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.css' rel='stylesheet' />
#     <script src='https://api.mapbox.com/mapbox-gl-js/plugins/mapbox-gl-language/v0.10.1/mapbox-gl-language.js'></script>
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#
#         #tooltip {
#             position: absolute;
#             z-index: 1;
#             pointer-events: none;
#             background-color: white;
#             border-radius: 10%;
#             padding: 10px;
#             font-size:12px;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
#     <div id='tooltip' id='tooltip'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#
#     const {MapboxLayer} = deck;
#     mapboxgl.accessToken = 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw';
#
#     const map = new mapboxgl.Map({
#         container: 'container',
#         style: 'mapbox://styles/mapbox/light-v9',
#         center: [126.81561169069604, 37.08218248972286],
#         zoom: 12,
#         pitch: 60,
#         bearing: 0
#     });
#
#     map.on('load', () => {
#
#
#
#
#             map.addLayer(new MapboxLayer(
#                 {
#     type: GridLayer,
#
#     // ScatterplotLayer Added.
#     cellSize: 200,
#     //to be updated. colorDomain: '[min(count), max(count)]',
#     colorRange: [[255, 255, 178], [254, 217, 118], [254, 178, 76], [253, 141, 60], [240, 59, 32], [189, 0, 38]],
#     coverage: 1,
#     //to be updated. elevationDomain: '[0, max(count)]',
#     elevationRange: [0, 1000],
#     elevationScale: 100,
#     extruded: true,
#     upperPercentile: 100,
#     lowerPercentile: 0,
#     elevationUpperPercentile: 100,
#     elevationLowerPercentile: 100,
#     //not supported. material: new PhongMaterial(),
#     getPosition: obj => obj.coordinates,
#     getColorValue: points => points.length,
#     getColorWeight: point => 1,
#     colorAggregation: 'SUM',
#     getElevationValue: points => points.length,
#     getElevationWeight: point => 1,
#     elevationAggregation: 'SUM',
#     onSetColorDomain: () => {},
#     onSetElevationDomain: () => {},
#
#     // BaseLayer (inherited)
#     'data' : [{'coordinates': [126.81561169069604, 37.08218248972286], 'values': 66}, {'coordinates': [126.82831786376109, 37.08140909828359], 'values': 23}, {'coordinates': [126.8387065894608, 37.06699779260753], 'values': 58}, {'coordinates': [126.84606088258417, 37.06672832706917], 'values': 39}, {'coordinates': [126.84662056554762, 37.037944216429445], 'values': 95}, {'coordinates': [126.8440176576777, 37.037963591237336], 'values': 5}, {'coordinates': [126.84591452407986, 37.066818241654104], 'values': 6}, {'coordinates': [126.83047144100027, 37.07895232384016], 'values': 39}, {'coordinates': [126.81582783195088, 37.082250988510175], 'values': 26}],
#     'id' : 'GridLayer',
#     'visible' : true,
#     'opacity' : 0.8,
#     'pickable' : false,
#     'onHover': info => setTooltip(info.object, info.x, info.y, null),
#     'onClick' : null,
#     'onDragStart' : null,
#     'onDrag' : null,
#     'onDragEnd' : null,
#     'highlightColor' : [0, 0, 128, 128],
#     'highlightedObjectIndex' : -1,
#     'autoHighlight' : false
# }
#             ));
#
#     });
#
#     var language = new MapboxLanguage({
#         defaultLanguage: 'ko'
#     });
#     map.addControl(language);
#
#
#
#
#     function setTooltip(object, x, y, tooltip) {
#         const el = document.getElementById('tooltip');
#
#         if (object) {
#             str_tooltip = '';
#             for (var i in tooltip) {
#                 item = tooltip[i]
#                 str_tooltip += item + ': ' + object[item] + '\n'
#             }
#             el.innerHTML = str_tooltip
#             el.style.display = 'block';
#             el.style.left = x + 'px';
#             el.style.top = y + 'px';
#         } else {
#             el.style.display = 'none';
#         }
#     }
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>

# %% [markdown]
# ## With Base Buildings

# %%
v = view_options.copy()
v['zoom'] = 17
m = Layer.Map(**v)
m.show(buildings=True)
# Out:
# <iframe id="map", srcdoc="<html>
#
# <head>
#     <script src='https://unpkg.com/deck.gl@7.2.0/dist.min.js'></script>
#     <script src='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.js'></script>
#     <link href='https://api.tiles.mapbox.com/mapbox-gl-js/v1.2.1/mapbox-gl.css' rel='stylesheet' />
#     <script src='https://api.mapbox.com/mapbox-gl-js/plugins/mapbox-gl-language/v0.10.1/mapbox-gl-language.js'></script>
#
#     <style type='text/css'>
#         body {
#             margin: 0;
#             padding: 0;
#         }
#
#         #container {
#             width: 100vw;
#             height: 100vh;
#         }
#
#         #tooltip {
#             position: absolute;
#             z-index: 1;
#             pointer-events: none;
#             background-color: white;
#             border-radius: 10%;
#             padding: 10px;
#             font-size:12px;
#         }
#     </style>
# </head>
#
# <body>
#     <div id='container'></div>
#     <div id='tooltip' id='tooltip'></div>
# </body>
#
# <script type='text/javascript'>
#     function colorToRGBArray(color) {
#     if (Array.isArray(color)) {
#         return color.slice(0, 4);
#     }
#     const c = rgb(color);
#     return [c.r, c.g, c.b, 255];
# }
#
#
#
#
#
#     const {MapboxLayer} = deck;
#     mapboxgl.accessToken = 'pk.eyJ1IjoiaGV1bXNpIiwiYSI6ImNqYng3ZW0xYTJsZHQycXBhM2F1bm9yMXIifQ.kV_zhG36r5EIXXT__LzlCw';
#
#     const map = new mapboxgl.Map({
#         container: 'container',
#         style: 'mapbox://styles/mapbox/light-v9',
#         center: [126.9086032, 37.17407153],
#         zoom: 17,
#         pitch: 60,
#         bearing: 0
#     });
#
#     map.on('load', () => {
#
#
#             const firstLabelLayerId = map.getStyle().layers.find(layer => layer.type === 'symbol').id;
#
#             map.addLayer({
#                 'id': '3d-buildings',
#                 'source': 'composite',
#                 'source-layer': 'building',
#                 'filter': ['==', 'extrude', 'true'],
#                 'type': 'fill-extrusion',
#                 'minzoom': 15,
#                 'paint': {
#                     'fill-extrusion-color': '#aaa',
#
#                     // use an 'interpolate' expression to add a smooth transition effect to the
#                     // buildings as the user zooms in
#                     'fill-extrusion-height': [
#                         'interpolate', ['linear'], ['zoom'],
#                         15, 0,
#                         15.05, ['get', 'height']
#                     ],
#                     'fill-extrusion-base': [
#                         'interpolate', ['linear'], ['zoom'],
#                         15, 0,
#                         15.05, ['get', 'min_height']
#                     ],
#                     'fill-extrusion-opacity': .6
#                 }
#                 }, firstLabelLayerId);
#
#
#
#     });
#
#     var language = new MapboxLanguage({
#         defaultLanguage: 'ko'
#     });
#     map.addControl(language);
#
#
#
#
#     function setTooltip(object, x, y, tooltip) {
#         const el = document.getElementById('tooltip');
#
#         if (object) {
#             str_tooltip = '';
#             for (var i in tooltip) {
#                 item = tooltip[i]
#                 str_tooltip += item + ': ' + object[item] + '\n'
#             }
#             el.innerHTML = str_tooltip
#             el.style.display = 'block';
#             el.style.left = x + 'px';
#             el.style.top = y + 'px';
#         } else {
#             el.style.display = 'none';
#         }
#     }
# </script>
#
#
# </html>" style="width: 100%; height: 700px;"></iframe>
